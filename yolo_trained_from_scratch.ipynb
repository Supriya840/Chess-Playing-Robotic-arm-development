# %% [markdown]
# <a href="https://colab.research.google.com/github/Supriya840/Chess-Playing-Robotic-arm-development/blob/main/yolo_trained_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir('/content/drive/MyDrive')

# %%
# !ls

# %%
# !git clone https://github.com/ultralytics/yolov5.git

# %%
os.chdir('yolov5')

# %%
ls

# %%
pip install -r requirements.txt

# %% [markdown]
# Training Yolo v5

# %%
# !python train.py --data data.yaml --cfg yolov5s.yaml --batch-size 8 --name Model --epochs 50

# %%
# !python export.py --weights runs/train/Model/weights/best.pt --include torchscript onnx
